# %%
# 27/05/26
import os                                     
import tensorflow as tf
from tensorflow.keras import layers, models                                  # type: ignore 
from tensorflow.keras.layers import Dropout                                  # type: ignore 
from tensorflow.keras.preprocessing.image import ImageDataGenerator          # type: ignore 

# For Model 3 onwards 
from tensorflow.keras.callbacks import EarlyStopping                         # type: ignore

# For Model 4
from tensorflow.keras.callbacks import ReduceLROnPlateau                     # type: ignore
from tensorflow.keras.layers import BatchNormalization                       # type: ignore
from tensorflow.keras.callbacks import ModelCheckpoint                       # type: ignore
import matplotlib.pyplot as plt

# %%
# SECTION 1 — TRAIN DATA AUGMENTATION : “image transformation machine” ----->  image processing pipeline ban rahi hai. (Optimized for pre-augmented data)

train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,             # 30 se kam karke 20 kiya (kyunki Augmentor ne pehle hi rotate kiya hai)
    zoom_range=0.1,                # 0.2 se kam karke 0.1 kiya taaki patta frame se bahar na nikal jaye
    horizontal_flip=True,          # Isko True rakho, ye hamesha sahi rehta hai
    vertical_flip=False,           # Isko False kar do (khet me patti aamtaur par ulti nahi lٹakti)
    width_shift_range=0.1,         # Shifting thodi kam ki
    height_shift_range=0.1,
    brightness_range=[0.9, 1.1],   # Lighting variations ko natural kiya (zyada extreme nahi)
    fill_mode='nearest'
)

# SECTION 2 - Validation data no augmentation (Same rahega)
val_datagen = ImageDataGenerator(rescale=1./255)

# %%
# SECTION 3: TRAIN GENERATOR
train_generator = train_datagen.flow_from_directory(
    'C:/Users/sanch/Documents/Git_hub/Streamlit-KrishiNetra/02_dataset/01_train',
    target_size=(224,224),
    batch_size= 32,
    class_mode='categorical',
    shuffle=True
)

# SECTION 4: VALIDATION GENERATOR
val_generator = val_datagen.flow_from_directory(
    'C:/Users/sanch/Documents/Git_hub/Streamlit-KrishiNetra/02_dataset/02_validate',
    target_size=(224,224),
    batch_size= 32,
    class_mode='categorical',
    shuffle=True
)
# Out:
# Found 5246 images belonging to 4 classes.
# Found 1122 images belonging to 4 classes.

# %%
model = models.Sequential()

# Block 1
model.add(layers.Conv2D(32, (3,3), activation='relu', padding='same', input_shape=(224,224,3)))
model.add(BatchNormalization())
model.add(layers.MaxPooling2D((2,2)))

# Block 2
model.add(layers.Conv2D(64, (3,3), activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(layers.MaxPooling2D((2,2)))

# Block 3
model.add(layers.Conv2D(128, (3,3), activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(layers.MaxPooling2D((2,2)))

# Block 4
model.add(layers.Conv2D(256, (3,3), activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(layers.MaxPooling2D((2,2)))

# Block 5 (Naya Heavy Block)
model.add(layers.Conv2D(512, (3,3), activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(layers.MaxPooling2D((2,2)))

# Global Feature Aggregation (Outputs a 512-d vector now)
model.add(layers.GlobalAveragePooling2D())

# Single, Strong Dense Layer
model.add(layers.Dense(256, activation='relu')) #  Tip: 512 se direct output compress karne ke liye isey 256 rakho, overfit rokesga
model.add(Dropout(0.42))                        #  Hard regularizer for real-world images

# Output Layer
model.add(layers.Dense(4, activation='softmax'))
# Out:
# c:\Users\sanch\Documents\Git_hub\Streamlit-KrishiNetra\krishi_env\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 224, 224, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 224, 224, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 112, 112, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 112, 112, 64)   │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 112, 112, 64)   │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 56, 56, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 56, 56, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 56, 56, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 28, 28, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 28, 28, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 28, 28, 256)    │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 14, 14, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 14, 14, 512)    │     1,180,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 14, 14, 512)    │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_4 (MaxPooling2D)  │ (None, 7, 7, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 512)            │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 4)              │         1,028 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,704,900 (6.50 MB)
#  Trainable params: 1,702,916 (6.50 MB)
#  Non-trainable params: 1,984 (7.75 KB)

# %%
# Compile Model

model.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])


# 1. Balanced Callbacks (Patience adjusted for heavy real-world data)
early_stop = EarlyStopping(
    monitor='val_loss', 
    patience= 5,                  # Badha kar 5 kiya taaki real-world patterns seekhne ka poora mauka mile
    restore_best_weights=True
)

lr_scheduler = ReduceLROnPlateau(
    monitor='val_loss', 
    factor = 0.2,                  # Sharp reduction for local minima escape
    patience = 3,                  # Wait for 3 epochs before dropping LR
    verbose = 1
)

checkpoint = ModelCheckpoint(
    '../04_models/model_apple_21.1.4.keras', 
    monitor = 'val_loss',
    save_best_only = True,
    verbose = 1
)

# 2. TRAINING (Removed class_weight parameter as dataset is now balanced at ~2k each)
print("\n Training started on Balanced Real-World Dataset ........")
history = model.fit(
    train_generator,
    validation_data = val_generator,
    epochs = 23,                   # 23 Epochs perfectly locked
    callbacks=[early_stop, lr_scheduler, checkpoint] 
)
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
#
#  Training started on Balanced Real-World Dataset ........
# Epoch 1/23
# 164/164 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6674 - loss: 1.0398
# Epoch 1: val_loss improved from None to 3.03096, saving model to ../04_models/model_apple_21.1.4.keras
#
# Epoch 1: finished saving model to ../04_models/model_apple_21.1.4.keras
# 164/164 ━━━━━━━━━━━━━━━━━━━━ 200s 1s/step - accuracy: 0.7429 - loss: 0.7723 - val_accuracy: 0.3663 - val_loss: 3.0310 - learning_rate: 0.0010
# Epoch 2/23
# 164/164 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8239 - loss: 0.5110
# Epoch 2: val_loss did not improve from 3.03096
# 164/164 ━━━━━━━━━━━━━━━━━━━━ 196s 1s/step - accuracy: 0.8403 - loss: 0.4681 - val_accuracy: 0.4572 - val_loss: 3.7748 - learning_rate: 0.0010
# Epoch 3/23
# 164/164 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8932 - loss: 0.3000
# Epoch 3: val_loss improved from 3.03096 to 1.06739, saving model to ../04_models/model_apple_21.1.4.keras
#
# Epoch 3: finished saving model to ../04_models/model_apple_21.1.4.keras
# 164/164 ━━━━━━━━━━━━━━━━━━━━ 196s 1s/step - accuracy: 0.8908 - loss: 0.3105 - val_accuracy: 0.6337 - val_loss: 1.0674 - learning_rate: 0.0010
# Epoch 4/23
# 164/164 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9180 - loss: 0.2472
# Epoch 4: val_loss improved from 1.06739 to 0.21291, saving model to ../04_models/model_apple_21.1.4.keras
#
# Epoch 4: finished saving model to ../04_models/model_apple_21.1.4.keras
# 164/164 ━━━━━━━━━━━━━━━━━━━━ 198s 1s/step - accuracy: 0.9238 - loss: 0.2338 - val_accuracy: 0.9403 - val_loss: 0.2129 - learning_rate: 0.0010
# Epoch 5/23
# 164/164 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9287 - loss: 0.1884
# Epoch 5: val_loss did not improve from 0.21291
# 164/164 ━━━━━━━━━━━━━━━━━━━━ 198s 1s/step - accuracy: 0.9388 - loss: 0.1742 - val_accuracy: 0.9207 - val_loss: 0.2516 - learning_rate: 0.0010
# Epoch 6/23
# 164/164 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9506 - loss: 0.1376
# Epoch 6: val_loss did not improve from 0.21291
# 164/164 ━━━━━━━━━━━━━━━━━━━━ 195s 1s/step - accuracy: 0.9497 - loss: 0.1454 - val_accuracy: 0.8859 - val_loss: 0.3558 - learning_rate: 0.0010
# Epoch 7/23
# 164/164 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9491 - loss: 0.1505
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
#
# Epoch 7: val_loss did not improve from 0.21291
# 164/164 ━━━━━━━━━━━━━━━━━━━━ 213s 1s/step - accuracy: 0.9531 - loss: 0.1354 - val_accuracy: 0.9162 - val_loss: 0.2378 - learning_rate: 0.0010
# Epoch 8/23
# 164/164 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9689 - loss: 0.0889
# Epoch 8: val_loss improved from 0.21291 to 0.10144, saving model to ../04_models/model_apple_21.1.4.keras
#
# Epoch 8: finished saving model to ../04_models/model_apple_21.1.4.keras
# 164/164 ━━━━━━━━━━━━━━━━━━━━ 219s 1s/step - accuracy: 0.9750 - loss: 0.0758 - val_accuracy: 0.9670 - val_loss: 0.1014 - learning_rate: 2.0000e-04
# Epoch 9/23
# 164/164 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9791 - loss: 0.0556
# Epoch 9: val_loss improved from 0.10144 to 0.06085, saving model to ../04_models/model_apple_21.1.4.keras
#
# Epoch 9: finished saving model to ../04_models/model_apple_21.1.4.keras
# 164/164 ━━━━━━━━━━━━━━━━━━━━ 218s 1s/step - accuracy: 0.9777 - loss: 0.0627 - val_accuracy: 0.9786 - val_loss: 0.0608 - learning_rate: 2.0000e-04
# Epoch 10/23
# 164/164 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9821 - loss: 0.0611
# Epoch 10: val_loss did not improve from 0.06085
# 164/164 ━━━━━━━━━━━━━━━━━━━━ 191s 1s/step - accuracy: 0.9834 - loss: 0.0564 - val_accuracy: 0.9777 - val_loss: 0.0732 - learning_rate: 2.0000e-04
# Epoch 11/23
# 164/164 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9857 - loss: 0.0480
# Epoch 11: val_loss improved from 0.06085 to 0.03913, saving model to ../04_models/model_apple_21.1.4.keras
#
# Epoch 11: finished saving model to ../04_models/model_apple_21.1.4.keras
# 164/164 ━━━━━━━━━━━━━━━━━━━━ 192s 1s/step - accuracy: 0.9851 - loss: 0.0515 - val_accuracy: 0.9857 - val_loss: 0.0391 - learning_rate: 2.0000e-04
# Epoch 12/23
# 164/164 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9850 - loss: 0.0465
# Epoch 12: val_loss did not improve from 0.03913
# 164/164 ━━━━━━━━━━━━━━━━━━━━ 198s 1s/step - accuracy: 0.9851 - loss: 0.0486 - val_accuracy: 0.9572 - val_loss: 0.1185 - learning_rate: 2.0000e-04
# Epoch 13/23
# 164/164 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9839 - loss: 0.0484
# Epoch 13: val_loss did not improve from 0.03913
# 164/164 ━━━━━━━━━━━━━━━━━━━━ 202s 1s/step - accuracy: 0.9861 - loss: 0.0458 - val_accuracy: 0.9786 - val_loss: 0.0646 - learning_rate: 2.0000e-04
# Epoch 14/23
# 164/164 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9866 - loss: 0.0381
# Epoch 14: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
#
# Epoch 14: val_loss did not improve from 0.03913
# 164/164 ━━━━━━━━━━━━━━━━━━━━ 198s 1s/step - accuracy: 0.9842 - loss: 0.0441 - val_accuracy: 0.9857 - val_loss: 0.0625 - learning_rate: 2.0000e-04
# Epoch 15/23
# 164/164 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9842 - loss: 0.0430
# Epoch 15: val_loss did not improve from 0.03913
# 164/164 ━━━━━━━━━━━━━━━━━━━━ 216s 1s/step - accuracy: 0.9876 - loss: 0.0377 - val_accuracy: 0.9875 - val_loss: 0.0440 - learning_rate: 4.0000e-05
# Epoch 16/23
# 164/164 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9923 - loss: 0.0318
# Epoch 16: val_loss improved from 0.03913 to 0.03832, saving model to ../04_models/model_apple_21.1.4.keras
#
# Epoch 16: finished saving model to ../04_models/model_apple_21.1.4.keras
# 164/164 ━━━━━━━━━━━━━━━━━━━━ 193s 1s/step - accuracy: 0.9905 - loss: 0.0338 - val_accuracy: 0.9866 - val_loss: 0.0383 - learning_rate: 4.0000e-05
# Epoch 17/23
# 164/164 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9910 - loss: 0.0294
# Epoch 17: val_loss did not improve from 0.03832
# 164/164 ━━━━━━━━━━━━━━━━━━━━ 199s 1s/step - accuracy: 0.9910 - loss: 0.0288 - val_accuracy: 0.9884 - val_loss: 0.0391 - learning_rate: 4.0000e-05
# Epoch 18/23
# 164/164 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9891 - loss: 0.0342
# Epoch 18: val_loss did not improve from 0.03832
# 164/164 ━━━━━━━━━━━━━━━━━━━━ 202s 1s/step - accuracy: 0.9909 - loss: 0.0303 - val_accuracy: 0.9866 - val_loss: 0.0440 - learning_rate: 4.0000e-05
# Epoch 19/23
# 164/164 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9914 - loss: 0.0264
# Epoch 19: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
#
# Epoch 19: val_loss did not improve from 0.03832
# 164/164 ━━━━━━━━━━━━━━━━━━━━ 190s 1s/step - accuracy: 0.9897 - loss: 0.0292 - val_accuracy: 0.9884 - val_loss: 0.0415 - learning_rate: 4.0000e-05
# Epoch 20/23
# 164/164 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9915 - loss: 0.0323
# Epoch 20: val_loss did not improve from 0.03832
# 164/164 ━━━━━━━━━━━━━━━━━━━━ 198s 1s/step - accuracy: 0.9907 - loss: 0.0306 - val_accuracy: 0.9893 - val_loss: 0.0428 - learning_rate: 8.0000e-06
# Epoch 21/23
# 164/164 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9909 - loss: 0.0285
# Epoch 21: val_loss did not improve from 0.03832
# 164/164 ━━━━━━━━━━━━━━━━━━━━ 202s 1s/step - accuracy: 0.9918 - loss: 0.0258 - val_accuracy: 0.9884 - val_loss: 0.0412 - learning_rate: 8.0000e-06

# %%
plt.figure(figsize=(12,5))

# Accuracy
plt.subplot(1,2,1)
plt.plot(history.history['accuracy'], label='Train')
plt.plot(history.history['val_accuracy'], label='Validation')
plt.title('Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)

# Loss
plt.subplot(1,2,2)
plt.plot(history.history['loss'], label='Train')
plt.plot(history.history['val_loss'], label='Validation')
plt.title('Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
# SECTION 5: TEST GENERATOR (For evaluation)
test_datagen = ImageDataGenerator(rescale=1./255)

test_generator = test_datagen.flow_from_directory(
    'C:/Users/sanch/Documents/Git_hub/Streamlit-KrishiNetra/02_dataset/03_test',
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical',
    shuffle=False  # CRITICAL: Isko False hi rakhna hai evaluation ke liye
)
# Out:
# Found 1122 images belonging to 4 classes.

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import classification_report, confusion_matrix

print("Evaluating model on test dataset...")

# 1. Test images par predictions nikalna
predictions = model.predict(test_generator, verbose=1)
predicted_classes = np.argmax(predictions, axis=1)
# Out:
# Evaluating model on test dataset...
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 7s 203ms/step

# %%
# 2. True (Original) labels nikalna
true_classes = test_generator.classes
class_labels = list(test_generator.class_indices.keys())

# %%
#  SECTION A: OVERALL TEST ACCURACY :Pura dataset par overall evaluation
test_loss, test_acc = model.evaluate(test_generator, verbose=0)
print("\n" + "="*50)
print(f"Final Test Accuracy: {test_acc*100:.2f}%")
print(f"Final Test Loss:     {test_loss:.4f}")
print("="*50 + "\n")
# Out:
# ==================================================
# Final Test Accuracy: 98.93%
# Final Test Loss:     0.0368
# ==================================================

# %%
# --- SECTION B: PRECISION, RECALL, F1-SCORE ---
print("Classification Report (Class-wise Performance):")
print(classification_report(true_classes, predicted_classes, target_names=class_labels))
# Out:
# Classification Report (Class-wise Performance):
#                           precision    recall  f1-score   support
#
#       Apple___Apple_scab       0.98      0.99      0.99       278
#        Apple___Black_rot       0.99      0.99      0.99       293
# Apple___Cedar_apple_rust       1.00      0.99      0.99       269
#          Apple___healthy       0.99      1.00      0.99       282
#
#                 accuracy                           0.99      1122
#                macro avg       0.99      0.99      0.99      1122
#             weighted avg       0.99      0.99      0.99      1122

# %%
# --- SECTION C: CONFUSION MATRIX ---
# Isse pata chalega kaun sa plant disease kis dusre disease ke sath confuse ho raha hai
cm = confusion_matrix(true_classes, predicted_classes)

plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', 
            xticklabels=class_labels, yticklabels=class_labels)
plt.title('Confusion Matrix - Apple :) Model')
plt.ylabel('Actual Classes')
plt.xlabel('Predicted Classes')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
