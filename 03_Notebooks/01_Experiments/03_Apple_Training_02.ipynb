# %%
# 29/05/26
import os                                     
import tensorflow as tf
from tensorflow.keras import layers, models                                  # type: ignore 
from tensorflow.keras.layers import Dropout                                  # type: ignore 
from tensorflow.keras.preprocessing.image import ImageDataGenerator          # type: ignore 

# For Model 3 onwards 
from tensorflow.keras.callbacks import EarlyStopping                         # type: ignore

# For Model 4
from tensorflow.keras.callbacks import ReduceLROnPlateau                     # type: ignore
from tensorflow.keras.layers import BatchNormalization                       # type: ignore
from tensorflow.keras.callbacks import ModelCheckpoint                       # type: ignore
import matplotlib.pyplot as plt

# %%
# SECTION 1 — TRAIN DATA AUGMENTATION : “image transformation machine” ----->  image processing pipeline ban rahi hai. (Optimized for pre-augmented data)

train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,             # 30 se kam karke 20 kiya (kyunki Augmentor ne pehle hi rotate kiya hai)
    zoom_range=0.1,                # 0.2 se kam karke 0.1 kiya taaki patta frame se bahar na nikal jaye
    horizontal_flip=True,          # Isko True rakho, ye hamesha sahi rehta hai
    vertical_flip=False,           # Isko False kar do (khet me patti aamtaur par ulti nahi lٹakti)
    width_shift_range=0.1,         # Shifting thodi kam ki
    height_shift_range=0.1,
    brightness_range=[0.9, 1.1],   # Lighting variations ko natural kiya (zyada extreme nahi)
    fill_mode='nearest'
)

# SECTION 2 - Validation data no augmentation (Same rahega)
val_datagen = ImageDataGenerator(rescale=1./255)

# %%
# SECTION 3: TRAIN GENERATOR
train_generator = train_datagen.flow_from_directory(
    'C:/Users/sanch/Documents/Git_hub/Streamlit-KrishiNetra/02_dataset/01_train',
    target_size=(224,224),
    batch_size= 32,
    class_mode='categorical',
    shuffle=True
)

# SECTION 4: VALIDATION GENERATOR
val_generator = val_datagen.flow_from_directory(
    'C:/Users/sanch/Documents/Git_hub/Streamlit-KrishiNetra/02_dataset/02_validate',
    target_size=(224,224),
    batch_size= 32,
    class_mode='categorical',
    shuffle=True
)
# Out:
# Found 5271 images belonging to 4 classes.
# Found 1122 images belonging to 4 classes.

# %%
model = models.Sequential()

# Block 1
model.add(layers.Conv2D(32, (3,3), activation='relu', padding='same', input_shape=(224,224,3)))
model.add(BatchNormalization())
model.add(layers.MaxPooling2D((2,2)))

# Block 2
model.add(layers.Conv2D(64, (3,3), activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(layers.MaxPooling2D((2,2)))

# Block 3
model.add(layers.Conv2D(128, (3,3), activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(layers.MaxPooling2D((2,2)))

# Block 4
model.add(layers.Conv2D(256, (3,3), activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(layers.MaxPooling2D((2,2)))

# Block 5 (Naya Heavy Block)
model.add(layers.Conv2D(512, (3,3), activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(layers.MaxPooling2D((2,2)))

# Global Feature Aggregation (Outputs a 512-d vector now)
model.add(layers.GlobalAveragePooling2D())

# Single, Strong Dense Layer
model.add(layers.Dense(256, activation='relu')) #  Tip: 512 se direct output compress karne ke liye isey 256 rakho, overfit rokesga
model.add(Dropout(0.38))                        #  Hard regularizer for real-world images

# Output Layer
model.add(layers.Dense(4, activation='softmax'))
# Out:
# c:\Users\sanch\Documents\Git_hub\Streamlit-KrishiNetra\krishi_env\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 224, 224, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 224, 224, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 112, 112, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 112, 112, 64)   │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 112, 112, 64)   │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 56, 56, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 56, 56, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 56, 56, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 28, 28, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 28, 28, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 28, 28, 256)    │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 14, 14, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 14, 14, 512)    │     1,180,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 14, 14, 512)    │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_4 (MaxPooling2D)  │ (None, 7, 7, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 512)            │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 4)              │         1,028 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,704,900 (6.50 MB)
#  Trainable params: 1,702,916 (6.50 MB)
#  Non-trainable params: 1,984 (7.75 KB)

# %%
# Compile Model

model.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])


# 1. Balanced Callbacks (Patience adjusted for heavy real-world data)
early_stop = EarlyStopping(
    monitor='val_loss', 
    patience= 5,                  # Badha kar 5 kiya taaki real-world patterns seekhne ka poora mauka mile
    restore_best_weights=True
)

lr_scheduler = ReduceLROnPlateau(
    monitor='val_loss', 
    factor = 0.2,                  # Sharp reduction for local minima escape
    patience = 3,                  # Wait for 3 epochs before dropping LR
    verbose = 1
)

checkpoint = ModelCheckpoint(
    '../04_models/model_apple_21.1.6.keras', 
    monitor = 'val_loss',
    save_best_only = True,
    verbose = 1
)

# 2. TRAINING (Removed class_weight parameter as dataset is now balanced at ~2k each)
print("\n Training started on Balanced Real-World Dataset ........")
history = model.fit(
    train_generator,
    validation_data = val_generator,
    epochs = 26,                   # 26 Epochs perfectly locked
    callbacks=[early_stop, lr_scheduler, checkpoint] 
)
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
#
#  Training started on Balanced Real-World Dataset ........
# Epoch 1/26
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 890ms/step - accuracy: 0.6339 - loss: 1.0751
# Epoch 1: val_loss improved from None to 4.21994, saving model to ../04_models/model_apple_21.1.6.keras
#
# Epoch 1: finished saving model to ../04_models/model_apple_21.1.6.keras
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 157s 934ms/step - accuracy: 0.7194 - loss: 0.7927 - val_accuracy: 0.2594 - val_loss: 4.2199 - learning_rate: 0.0010
# Epoch 2/26
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 871ms/step - accuracy: 0.8372 - loss: 0.4452
# Epoch 2: val_loss improved from 4.21994 to 3.83831, saving model to ../04_models/model_apple_21.1.6.keras
#
# Epoch 2: finished saving model to ../04_models/model_apple_21.1.6.keras
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 151s 913ms/step - accuracy: 0.8570 - loss: 0.4050 - val_accuracy: 0.4171 - val_loss: 3.8383 - learning_rate: 0.0010
# Epoch 3/26
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 893ms/step - accuracy: 0.8988 - loss: 0.2800
# Epoch 3: val_loss improved from 3.83831 to 1.63115, saving model to ../04_models/model_apple_21.1.6.keras
#
# Epoch 3: finished saving model to ../04_models/model_apple_21.1.6.keras
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 155s 936ms/step - accuracy: 0.9013 - loss: 0.2750 - val_accuracy: 0.5971 - val_loss: 1.6311 - learning_rate: 0.0010
# Epoch 4/26
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 861ms/step - accuracy: 0.9127 - loss: 0.2340
# Epoch 4: val_loss improved from 1.63115 to 0.52263, saving model to ../04_models/model_apple_21.1.6.keras
#
# Epoch 4: finished saving model to ../04_models/model_apple_21.1.6.keras
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 149s 902ms/step - accuracy: 0.9199 - loss: 0.2238 - val_accuracy: 0.8280 - val_loss: 0.5226 - learning_rate: 0.0010
# Epoch 5/26
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 862ms/step - accuracy: 0.9342 - loss: 0.1959
# Epoch 5: val_loss did not improve from 0.52263
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 149s 903ms/step - accuracy: 0.9336 - loss: 0.1917 - val_accuracy: 0.7166 - val_loss: 1.0125 - learning_rate: 0.0010
# Epoch 6/26
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 866ms/step - accuracy: 0.9454 - loss: 0.1535
# Epoch 6: val_loss improved from 0.52263 to 0.28396, saving model to ../04_models/model_apple_21.1.6.keras
#
# Epoch 6: finished saving model to ../04_models/model_apple_21.1.6.keras
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 150s 905ms/step - accuracy: 0.9459 - loss: 0.1551 - val_accuracy: 0.9020 - val_loss: 0.2840 - learning_rate: 0.0010
# Epoch 7/26
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 871ms/step - accuracy: 0.9571 - loss: 0.1140
# Epoch 7: val_loss improved from 0.28396 to 0.25599, saving model to ../04_models/model_apple_21.1.6.keras
#
# Epoch 7: finished saving model to ../04_models/model_apple_21.1.6.keras
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 150s 911ms/step - accuracy: 0.9567 - loss: 0.1214 - val_accuracy: 0.9109 - val_loss: 0.2560 - learning_rate: 0.0010
# Epoch 8/26
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 867ms/step - accuracy: 0.9639 - loss: 0.1071
# Epoch 8: val_loss did not improve from 0.25599
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 150s 908ms/step - accuracy: 0.9548 - loss: 0.1389 - val_accuracy: 0.8904 - val_loss: 0.3423 - learning_rate: 0.0010
# Epoch 9/26
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 883ms/step - accuracy: 0.9592 - loss: 0.1184
# Epoch 9: val_loss did not improve from 0.25599
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 152s 920ms/step - accuracy: 0.9605 - loss: 0.1153 - val_accuracy: 0.8244 - val_loss: 0.5504 - learning_rate: 0.0010
# Epoch 10/26
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 855ms/step - accuracy: 0.9688 - loss: 0.0933
# Epoch 10: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
#
# Epoch 10: val_loss did not improve from 0.25599
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 148s 894ms/step - accuracy: 0.9632 - loss: 0.1059 - val_accuracy: 0.6390 - val_loss: 1.3608 - learning_rate: 0.0010
# Epoch 11/26
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 862ms/step - accuracy: 0.9754 - loss: 0.0684
# Epoch 11: val_loss improved from 0.25599 to 0.07112, saving model to ../04_models/model_apple_21.1.6.keras
#
# Epoch 11: finished saving model to ../04_models/model_apple_21.1.6.keras
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 149s 900ms/step - accuracy: 0.9769 - loss: 0.0649 - val_accuracy: 0.9733 - val_loss: 0.0711 - learning_rate: 2.0000e-04
# Epoch 12/26
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 858ms/step - accuracy: 0.9837 - loss: 0.0507
# Epoch 12: val_loss improved from 0.07112 to 0.04345, saving model to ../04_models/model_apple_21.1.6.keras
#
# Epoch 12: finished saving model to ../04_models/model_apple_21.1.6.keras
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 148s 897ms/step - accuracy: 0.9835 - loss: 0.0478 - val_accuracy: 0.9875 - val_loss: 0.0435 - learning_rate: 2.0000e-04
# Epoch 13/26
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 855ms/step - accuracy: 0.9846 - loss: 0.0508
# Epoch 13: val_loss did not improve from 0.04345
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 148s 895ms/step - accuracy: 0.9848 - loss: 0.0479 - val_accuracy: 0.9804 - val_loss: 0.0507 - learning_rate: 2.0000e-04
# Epoch 14/26
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 850ms/step - accuracy: 0.9862 - loss: 0.0437
# Epoch 14: val_loss improved from 0.04345 to 0.03426, saving model to ../04_models/model_apple_21.1.6.keras
#
# Epoch 14: finished saving model to ../04_models/model_apple_21.1.6.keras
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 147s 891ms/step - accuracy: 0.9863 - loss: 0.0428 - val_accuracy: 0.9902 - val_loss: 0.0343 - learning_rate: 2.0000e-04
# Epoch 15/26
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 859ms/step - accuracy: 0.9847 - loss: 0.0534
# Epoch 15: val_loss did not improve from 0.03426
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 148s 896ms/step - accuracy: 0.9852 - loss: 0.0494 - val_accuracy: 0.9822 - val_loss: 0.0481 - learning_rate: 2.0000e-04
# Epoch 16/26
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 878ms/step - accuracy: 0.9844 - loss: 0.0409
# Epoch 16: val_loss did not improve from 0.03426
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 152s 920ms/step - accuracy: 0.9871 - loss: 0.0398 - val_accuracy: 0.9848 - val_loss: 0.0473 - learning_rate: 2.0000e-04
# Epoch 17/26
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 860ms/step - accuracy: 0.9886 - loss: 0.0377
# Epoch 17: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
#
# Epoch 17: val_loss did not improve from 0.03426
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 148s 898ms/step - accuracy: 0.9884 - loss: 0.0369 - val_accuracy: 0.9866 - val_loss: 0.0460 - learning_rate: 2.0000e-04
# Epoch 18/26
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 847ms/step - accuracy: 0.9909 - loss: 0.0309
# Epoch 18: val_loss did not improve from 0.03426
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 147s 888ms/step - accuracy: 0.9896 - loss: 0.0321 - val_accuracy: 0.9866 - val_loss: 0.0443 - learning_rate: 4.0000e-05
# Epoch 19/26
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 850ms/step - accuracy: 0.9890 - loss: 0.0307
# Epoch 19: val_loss improved from 0.03426 to 0.03324, saving model to ../04_models/model_apple_21.1.6.keras
#
# Epoch 19: finished saving model to ../04_models/model_apple_21.1.6.keras
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 147s 888ms/step - accuracy: 0.9892 - loss: 0.0313 - val_accuracy: 0.9884 - val_loss: 0.0332 - learning_rate: 4.0000e-05
# Epoch 20/26
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 861ms/step - accuracy: 0.9918 - loss: 0.0272
# Epoch 20: val_loss did not improve from 0.03324
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 149s 900ms/step - accuracy: 0.9920 - loss: 0.0266 - val_accuracy: 0.9893 - val_loss: 0.0341 - learning_rate: 4.0000e-05
# Epoch 21/26
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 874ms/step - accuracy: 0.9908 - loss: 0.0270
# Epoch 21: val_loss did not improve from 0.03324
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 151s 917ms/step - accuracy: 0.9922 - loss: 0.0232 - val_accuracy: 0.9884 - val_loss: 0.0335 - learning_rate: 4.0000e-05
# Epoch 22/26
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 860ms/step - accuracy: 0.9936 - loss: 0.0237
# Epoch 22: val_loss improved from 0.03324 to 0.03020, saving model to ../04_models/model_apple_21.1.6.keras
#
# Epoch 22: finished saving model to ../04_models/model_apple_21.1.6.keras
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 149s 903ms/step - accuracy: 0.9928 - loss: 0.0265 - val_accuracy: 0.9884 - val_loss: 0.0302 - learning_rate: 4.0000e-05
# Epoch 23/26
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 878ms/step - accuracy: 0.9935 - loss: 0.0210
# Epoch 23: val_loss did not improve from 0.03020
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 152s 920ms/step - accuracy: 0.9915 - loss: 0.0281 - val_accuracy: 0.9902 - val_loss: 0.0343 - learning_rate: 4.0000e-05
# Epoch 24/26
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 860ms/step - accuracy: 0.9895 - loss: 0.0247
# Epoch 24: val_loss did not improve from 0.03020
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 149s 900ms/step - accuracy: 0.9898 - loss: 0.0280 - val_accuracy: 0.9884 - val_loss: 0.0310 - learning_rate: 4.0000e-05
# Epoch 25/26
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 874ms/step - accuracy: 0.9939 - loss: 0.0211
# Epoch 25: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
#
# Epoch 25: val_loss did not improve from 0.03020
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 151s 915ms/step - accuracy: 0.9928 - loss: 0.0238 - val_accuracy: 0.9902 - val_loss: 0.0308 - learning_rate: 4.0000e-05
# Epoch 26/26
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 858ms/step - accuracy: 0.9924 - loss: 0.0237
# Epoch 26: val_loss did not improve from 0.03020
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 149s 900ms/step - accuracy: 0.9932 - loss: 0.0228 - val_accuracy: 0.9902 - val_loss: 0.0304 - learning_rate: 8.0000e-06

# %%
plt.figure(figsize=(12,5))

# Accuracy
plt.subplot(1,2,1)
plt.plot(history.history['accuracy'], label='Train')
plt.plot(history.history['val_accuracy'], label='Validation')
plt.title('Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)

# Loss
plt.subplot(1,2,2)
plt.plot(history.history['loss'], label='Train')
plt.plot(history.history['val_loss'], label='Validation')
plt.title('Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
# SECTION 5: TEST GENERATOR (For evaluation)
test_datagen = ImageDataGenerator(rescale=1./255)

test_generator = test_datagen.flow_from_directory(
    'C:/Users/sanch/Documents/Git_hub/Streamlit-KrishiNetra/02_dataset/03_test',
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical',
    shuffle=False  # CRITICAL: Isko False hi rakhna hai evaluation ke liye
)
# Out:
# Found 1121 images belonging to 4 classes.

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import classification_report, confusion_matrix

print("Evaluating model on test dataset...")

# 1. Test images par predictions nikalna
predictions = model.predict(test_generator, verbose=1)
predicted_classes = np.argmax(predictions, axis=1)
# Out:
# Evaluating model on test dataset...
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 7s 180ms/step

# %%
# 2. True (Original) labels nikalna
true_classes = test_generator.classes
class_labels = list(test_generator.class_indices.keys())

# %%
#  SECTION A: OVERALL TEST ACCURACY :Pura dataset par overall evaluation
test_loss, test_acc = model.evaluate(test_generator, verbose=0)
print("\n" + "="*50)
print(f"Final Test Accuracy: {test_acc*100:.2f}%")
print(f"Final Test Loss:     {test_loss:.4f}")
print("="*50 + "\n")
# Out:
# ==================================================
# Final Test Accuracy: 99.02%
# Final Test Loss:     0.0238
# ==================================================

# %%
# --- SECTION B: PRECISION, RECALL, F1-SCORE ---
print("Classification Report (Class-wise Performance):")
print(classification_report(true_classes, predicted_classes, target_names=class_labels))
# Out:
# Classification Report (Class-wise Performance):
#                           precision    recall  f1-score   support
#
#       Apple___Apple_scab       0.99      0.98      0.99       278
#        Apple___Black_rot       0.99      0.99      0.99       292
# Apple___Cedar_apple_rust       0.99      0.99      0.99       269
#          Apple___healthy       0.99      1.00      1.00       282
#
#                 accuracy                           0.99      1121
#                macro avg       0.99      0.99      0.99      1121
#             weighted avg       0.99      0.99      0.99      1121

# %%
# --- SECTION C: CONFUSION MATRIX ---
# Isse pata chalega kaun sa plant disease kis dusre disease ke sath confuse ho raha hai
cm = confusion_matrix(true_classes, predicted_classes)

plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', 
            xticklabels=class_labels, yticklabels=class_labels)
plt.title('Confusion Matrix - Apple :) Model')
plt.ylabel('Actual Classes')
plt.xlabel('Predicted Classes')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
