# %%
# 12/06/26
import os                                     
import tensorflow as tf
from tensorflow.keras import layers, models                                  # type: ignore 
from tensorflow.keras.layers import Dropout                                  # type: ignore 
from tensorflow.keras.preprocessing.image import ImageDataGenerator          # type: ignore 

# For Model 3 onwards 
from tensorflow.keras.callbacks import EarlyStopping                         # type: ignore

# For Model 4
from tensorflow.keras.callbacks import ReduceLROnPlateau                     # type: ignore
from tensorflow.keras.layers import BatchNormalization                        # type: ignore
from tensorflow.keras.callbacks import ModelCheckpoint                       # type: ignore
import matplotlib.pyplot as plt

# %%
# SECTION 1 — TRAIN DATA AUGMENTATION : “image transformation machine” ----->  image processing pipeline ban rahi hai. (Optimized for pre-augmented data)

train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,            # 30 se kam karke 20 kiya (kyunki Augmentor ne pehle hi rotate kiya hai)
    zoom_range=0.1,               # 0.2 se kam karke 0.1 kiya taaki patta frame se bahar na nikal jaye
    horizontal_flip=True,         # Isko True rakho, ye hamesha sahi rehta hai
    vertical_flip=False,          # Isko False kar do (khet me patti aamtaur par ulti nahi latakti)
    width_shift_range=0.1,        # Shifting thodi kam ki
    height_shift_range=0.1,
    brightness_range=[0.9, 1.2],  # Lighting variations ko natural kiya (zyada extreme nahi)
    fill_mode='nearest'
)

# SECTION 2 - Validation data no augmentation (Same rahega)
val_datagen = ImageDataGenerator(rescale=1./255)

# %%
# SECTION 3: TRAIN GENERATOR
train_generator = train_datagen.flow_from_directory(
    'C:/Users/sanch/Documents/Git_hub/Streamlit-KrishiNetra/02_dataset/01_train',
    target_size=(224,224),
    batch_size= 32,
    class_mode='categorical',
    shuffle=True
)

# SECTION 4: VALIDATION GENERATOR
val_generator = val_datagen.flow_from_directory(
    'C:/Users/sanch/Documents/Git_hub/Streamlit-KrishiNetra/02_dataset/02_validate',
    target_size=(224,224),
    batch_size= 32,
    class_mode='categorical',
    shuffle=True
)
# Out:
# Found 5339 images belonging to 4 classes.
# Found 1003 images belonging to 4 classes.

# %%
class_names = list(train_generator.class_indices.keys())
print(class_names)
# Out:
# ['Tomato___Late_blight', 'Tomato___Leaf_Mold', 'Tomato___Septoria_leaf_spot', 'Tomato___healthy']

# %%
model = models.Sequential()

# Block 1
model.add(layers.Conv2D(32, (3,3), activation='relu', padding='same', input_shape=(224,224,3)))
model.add(BatchNormalization())
model.add(layers.MaxPooling2D((2,2)))

# Block 2
model.add(layers.Conv2D(64, (3,3), activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(layers.MaxPooling2D((2,2)))

# Block 3
model.add(layers.Conv2D(128, (3,3), activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(layers.MaxPooling2D((2,2)))

# Block 4
model.add(layers.Conv2D(256, (3,3), activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(layers.MaxPooling2D((2,2)))

# Block 5 (Naya Heavy Block)
model.add(layers.Conv2D(512, (3,3), activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(layers.MaxPooling2D((2,2)))

# Global Feature Aggregation (Outputs a 512-d vector now)
model.add(layers.GlobalAveragePooling2D())

# Single, Strong Dense Layer
model.add(layers.Dense(256, activation='relu')) #  Tip: 512 se direct output compress karne ke liye isey 256 rakho, overfit rokesga
model.add(Dropout(0.43))                        #  Hard regularizer for real-world images

# Output Layer
model.add(layers.Dense(4, activation='softmax'))
# Out:
# c:\Users\sanch\Documents\Git_hub\Streamlit-KrishiNetra\krishi_env\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 224, 224, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 224, 224, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 112, 112, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 112, 112, 64)   │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 112, 112, 64)   │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 56, 56, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 56, 56, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 56, 56, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 28, 28, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 28, 28, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 28, 28, 256)    │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 14, 14, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 14, 14, 512)    │     1,180,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 14, 14, 512)    │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_4 (MaxPooling2D)  │ (None, 7, 7, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 512)            │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 4)              │         1,028 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,704,900 (6.50 MB)
#  Trainable params: 1,702,916 (6.50 MB)
#  Non-trainable params: 1,984 (7.75 KB)

# %%
# UPDATED TRAINING BLOCK 

# Compile Model
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])



# 1. Balanced Callbacks (Patience adjusted for heavy real-world data)
early_stop = EarlyStopping(
    monitor='val_loss', 
    patience=7,                  # Badha kar 5 kiya taaki real-world patterns seekhne ka poora mauka mile
    restore_best_weights=True
)

lr_scheduler = ReduceLROnPlateau(
    monitor='val_loss', 
    factor=0.2,                  # Sharp reduction for local minima escape
    patience=3,                  # Wait for 3 epochs before dropping LR
    verbose=1
)

checkpoint = ModelCheckpoint(
    '../04_models/model_tomato_1.0.6.keras', 
    monitor='val_loss',
    save_best_only=True,
    verbose=1
)

# 2. TRAINING (Removed class_weight parameter as dataset is now balanced at ~2k each)
print("\n Training started on Balanced Real-World Dataset ........")
history = model.fit(
    train_generator,
    validation_data = val_generator,
    epochs= 40,                    # 40 Epochs perfectly locked
    callbacks=[early_stop, lr_scheduler, checkpoint] 
)
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
#
#  Training started on Balanced Real-World Dataset ........
# Epoch 1/40
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6560 - loss: 0.9853
# Epoch 1: val_loss improved from None to 4.33270, saving model to ../04_models/model_tomato_1.0.6.keras
#
# Epoch 1: finished saving model to ../04_models/model_tomato_1.0.6.keras
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 216s 1s/step - accuracy: 0.7573 - loss: 0.6675 - val_accuracy: 0.2522 - val_loss: 4.3327 - learning_rate: 0.0010
# Epoch 2/40
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8501 - loss: 0.4127
# Epoch 2: val_loss improved from 4.33270 to 3.41338, saving model to ../04_models/model_tomato_1.0.6.keras
#
# Epoch 2: finished saving model to ../04_models/model_tomato_1.0.6.keras
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 198s 1s/step - accuracy: 0.8560 - loss: 0.3954 - val_accuracy: 0.4457 - val_loss: 3.4134 - learning_rate: 0.0010
# Epoch 3/40
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8803 - loss: 0.3370
# Epoch 3: val_loss improved from 3.41338 to 1.24860, saving model to ../04_models/model_tomato_1.0.6.keras
#
# Epoch 3: finished saving model to ../04_models/model_tomato_1.0.6.keras
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 225s 1s/step - accuracy: 0.8872 - loss: 0.3243 - val_accuracy: 0.6231 - val_loss: 1.2486 - learning_rate: 0.0010
# Epoch 4/40
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9201 - loss: 0.2305
# Epoch 4: val_loss did not improve from 1.24860
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 232s 1s/step - accuracy: 0.9133 - loss: 0.2488 - val_accuracy: 0.5593 - val_loss: 2.0481 - learning_rate: 0.0010
# Epoch 5/40
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9247 - loss: 0.2233
# Epoch 5: val_loss improved from 1.24860 to 0.93688, saving model to ../04_models/model_tomato_1.0.6.keras
#
# Epoch 5: finished saving model to ../04_models/model_tomato_1.0.6.keras
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 240s 1s/step - accuracy: 0.9294 - loss: 0.2128 - val_accuracy: 0.7378 - val_loss: 0.9369 - learning_rate: 0.0010
# Epoch 6/40
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9316 - loss: 0.1902
# Epoch 6: val_loss did not improve from 0.93688
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 222s 1s/step - accuracy: 0.9384 - loss: 0.1791 - val_accuracy: 0.6251 - val_loss: 1.8530 - learning_rate: 0.0010
# Epoch 7/40
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9395 - loss: 0.1805
# Epoch 7: val_loss improved from 0.93688 to 0.45215, saving model to ../04_models/model_tomato_1.0.6.keras
#
# Epoch 7: finished saving model to ../04_models/model_tomato_1.0.6.keras
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 212s 1s/step - accuracy: 0.9382 - loss: 0.1797 - val_accuracy: 0.8524 - val_loss: 0.4521 - learning_rate: 0.0010
# Epoch 8/40
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9468 - loss: 0.1556
# Epoch 8: val_loss improved from 0.45215 to 0.32569, saving model to ../04_models/model_tomato_1.0.6.keras
#
# Epoch 8: finished saving model to ../04_models/model_tomato_1.0.6.keras
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 203s 1s/step - accuracy: 0.9549 - loss: 0.1392 - val_accuracy: 0.8973 - val_loss: 0.3257 - learning_rate: 0.0010
# Epoch 9/40
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9629 - loss: 0.1081
# Epoch 9: val_loss did not improve from 0.32569
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 210s 1s/step - accuracy: 0.9590 - loss: 0.1131 - val_accuracy: 0.7208 - val_loss: 1.1554 - learning_rate: 0.0010
# Epoch 10/40
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9653 - loss: 0.0969
# Epoch 10: val_loss did not improve from 0.32569
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 206s 1s/step - accuracy: 0.9629 - loss: 0.1087 - val_accuracy: 0.7119 - val_loss: 1.2383 - learning_rate: 0.0010
# Epoch 11/40
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9572 - loss: 0.1266
# Epoch 11: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
#
# Epoch 11: val_loss did not improve from 0.32569
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 213s 1s/step - accuracy: 0.9601 - loss: 0.1230 - val_accuracy: 0.6770 - val_loss: 2.0593 - learning_rate: 0.0010
# Epoch 12/40
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9773 - loss: 0.0705
# Epoch 12: val_loss improved from 0.32569 to 0.07191, saving model to ../04_models/model_tomato_1.0.6.keras
#
# Epoch 12: finished saving model to ../04_models/model_tomato_1.0.6.keras
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 213s 1s/step - accuracy: 0.9807 - loss: 0.0599 - val_accuracy: 0.9801 - val_loss: 0.0719 - learning_rate: 2.0000e-04
# Epoch 13/40
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9869 - loss: 0.0438
# Epoch 13: val_loss did not improve from 0.07191
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 199s 1s/step - accuracy: 0.9876 - loss: 0.0451 - val_accuracy: 0.9432 - val_loss: 0.2290 - learning_rate: 2.0000e-04
# Epoch 14/40
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9863 - loss: 0.0365
# Epoch 14: val_loss did not improve from 0.07191
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 195s 1s/step - accuracy: 0.9846 - loss: 0.0418 - val_accuracy: 0.9721 - val_loss: 0.1281 - learning_rate: 2.0000e-04
# Epoch 15/40
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9882 - loss: 0.0423
# Epoch 15: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
#
# Epoch 15: val_loss did not improve from 0.07191
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 207s 1s/step - accuracy: 0.9876 - loss: 0.0401 - val_accuracy: 0.9821 - val_loss: 0.0731 - learning_rate: 2.0000e-04
# Epoch 16/40
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9927 - loss: 0.0284
# Epoch 16: val_loss improved from 0.07191 to 0.06199, saving model to ../04_models/model_tomato_1.0.6.keras
#
# Epoch 16: finished saving model to ../04_models/model_tomato_1.0.6.keras
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 225s 1s/step - accuracy: 0.9899 - loss: 0.0320 - val_accuracy: 0.9840 - val_loss: 0.0620 - learning_rate: 4.0000e-05
# Epoch 17/40
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9941 - loss: 0.0230
# Epoch 17: val_loss did not improve from 0.06199
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 221s 1s/step - accuracy: 0.9925 - loss: 0.0280 - val_accuracy: 0.9840 - val_loss: 0.0711 - learning_rate: 4.0000e-05
# Epoch 18/40
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9900 - loss: 0.0302
# Epoch 18: val_loss did not improve from 0.06199
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 229s 1s/step - accuracy: 0.9893 - loss: 0.0288 - val_accuracy: 0.9850 - val_loss: 0.0668 - learning_rate: 4.0000e-05
# Epoch 19/40
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9930 - loss: 0.0267
# Epoch 19: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
#
# Epoch 19: val_loss did not improve from 0.06199
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 217s 1s/step - accuracy: 0.9933 - loss: 0.0250 - val_accuracy: 0.9831 - val_loss: 0.0829 - learning_rate: 4.0000e-05
# Epoch 20/40
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9905 - loss: 0.0290
# Epoch 20: val_loss did not improve from 0.06199
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 211s 1s/step - accuracy: 0.9899 - loss: 0.0295 - val_accuracy: 0.9801 - val_loss: 0.0809 - learning_rate: 8.0000e-06
# Epoch 21/40
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9913 - loss: 0.0293
# Epoch 21: val_loss did not improve from 0.06199
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 231s 1s/step - accuracy: 0.9914 - loss: 0.0262 - val_accuracy: 0.9840 - val_loss: 0.0805 - learning_rate: 8.0000e-06
# Epoch 22/40
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9898 - loss: 0.0303
# Epoch 22: ReduceLROnPlateau reducing learning rate to 1.6000001778593287e-06.
#
# Epoch 22: val_loss did not improve from 0.06199
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 221s 1s/step - accuracy: 0.9910 - loss: 0.0278 - val_accuracy: 0.9840 - val_loss: 0.0781 - learning_rate: 8.0000e-06
# Epoch 23/40
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9916 - loss: 0.0304
# Epoch 23: val_loss did not improve from 0.06199
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 212s 1s/step - accuracy: 0.9914 - loss: 0.0274 - val_accuracy: 0.9831 - val_loss: 0.0798 - learning_rate: 1.6000e-06

# %%
plt.figure(figsize=(12,5))

# Accuracy
plt.subplot(1,2,1)
plt.plot(history.history['accuracy'], label='Train')
plt.plot(history.history['val_accuracy'], label='Validation')
plt.title('Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)

# Loss
plt.subplot(1,2,2)
plt.plot(history.history['loss'], label='Train')
plt.plot(history.history['val_loss'], label='Validation')
plt.title('Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
# SECTION 5: TEST GENERATOR (For evaluation)
test_datagen = ImageDataGenerator(rescale=1./255)

test_generator = test_datagen.flow_from_directory(
    'C:/Users/sanch/Documents/Git_hub/Streamlit-KrishiNetra/02_dataset/03_test',
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical',
    shuffle=False  # CRITICAL: Isko False hi rakhna hai evaluation ke liye
)
# Out:
# Found 330 images belonging to 4 classes.

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import classification_report, confusion_matrix

print("Evaluating model on test dataset...")

# 1. Test images par predictions nikalna
predictions = model.predict(test_generator, verbose=1)
predicted_classes = np.argmax(predictions, axis=1)
# Out:
# Evaluating model on test dataset...
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 277ms/step

# %%
# 2. True (Original) labels nikalna
true_classes = test_generator.classes
class_labels = list(test_generator.class_indices.keys())

# %%
#  SECTION A: OVERALL TEST ACCURACY :Pura dataset par overall evaluation
test_loss, test_acc = model.evaluate(test_generator, verbose=0)
print("\n" + "="*50)
print(f"Final Test Accuracy: {test_acc*100:.2f}%")
print(f"Final Test Loss:     {test_loss:.4f}")
print("="*50 + "\n")
# Out:
# ==================================================
# Final Test Accuracy: 97.58%
# Final Test Loss:     0.0913
# ==================================================

# %%
# --- SECTION B: PRECISION, RECALL, F1-SCORE ---
print("Classification Report (Class-wise Performance):")
print(classification_report(true_classes, predicted_classes, target_names=class_labels))
# Out:
# Classification Report (Class-wise Performance):
#                              precision    recall  f1-score   support
#
#        Tomato___Late_blight       1.00      0.96      0.98        84
#          Tomato___Leaf_Mold       0.99      0.97      0.98        80
# Tomato___Septoria_leaf_spot       0.99      0.96      0.97        80
#            Tomato___healthy       0.93      1.00      0.97        86
#
#                    accuracy                           0.98       330
#                   macro avg       0.98      0.98      0.98       330
#                weighted avg       0.98      0.98      0.98       330

# %%
# --- SECTION C: CONFUSION MATRIX ---
# Isse pata chalega kaun sa plant disease kis dusre disease ke sath confuse ho raha hai
cm = confusion_matrix(true_classes, predicted_classes)

plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', 
            xticklabels=class_labels, yticklabels=class_labels)
plt.title('Confusion Matrix - Tomato Model')
plt.ylabel('Actual Classes')
plt.xlabel('Predicted Classes')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
